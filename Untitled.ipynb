# %% [markdown]
# <a href="https://colab.research.google.com/github/Raiyat/Pytorch-project/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print('Hell')
# Out:
# Hell

# %%
print('My baby')
# Out:
# My baby
